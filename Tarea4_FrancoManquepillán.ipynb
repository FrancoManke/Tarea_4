# %% [markdown]
# # Tarea 4
#
# ### Franco Manquepillán Calfuleo
# ### Ing. Civil Industrial m bioprocesos
# ### Profesora: Darlin Soto

# %%
pip install pyreadstat
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyreadstat

# %%
# Leer el archivo .sav
archivo_sav = "Casen_2017.sav"
datos, metadatos = pyreadstat.read_sav(archivo_sav)
datos.info()
datos.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216439 entries, 0 to 216438
# Columns: 804 entries, folio to pobreza_multi_5d
# dtypes: float64(768), object(36)
# memory usage: 1.3+ GB
#           folio    o   id_vivienda  hogar  region  provincia  comuna  zona  \
# 0  1.101100e+11  1.0  1.101100e+09    1.0     1.0       11.0  1101.0   1.0
# 1  1.101100e+11  1.0  1.101100e+09    1.0     1.0       11.0  1101.0   1.0
# 2  1.101100e+11  1.0  1.101100e+09    1.0     1.0       11.0  1101.0   1.0
# 3  1.101100e+11  2.0  1.101100e+09    1.0     1.0       11.0  1101.0   1.0
# 4  1.101100e+11  1.0  1.101100e+09    1.0     1.0       11.0  1101.0   1.0
#
#    expr  expc  ...  hh_d_estado  hh_d_servbas  hh_d_entorno  hh_d_accesi  \
# 0  39.0  33.0  ...          0.0           1.0           1.0          0.0
# 1  39.0  33.0  ...          1.0           0.0           0.0          0.0
# 2  39.0  33.0  ...          1.0           0.0           1.0          0.0
# ...

# %% [markdown]
# Preguntas
#
# - 1. Muestre, por sexo y región, cuántos/as encuenstados fueron pesquisadas en la encuesta CASEN 2017. Nombre las tres grandes regiones donde se concentra la mayor población.
#
# Las tres grandes regiones dónde se observa la concentración de población es en Región Metropolitana, Biobío y Valparaíso.
#
# Las variables a utilizar corresponden al conteo de personas "sexo" y "región". Esto nos cruza la información de cuántos/as respondieron en relación a si es del sexo femenino o masculino y de qué región es.
#
# - 2. ¿Cuál es el porcentaje de encuestados en la zona rural y la zona urbana en Chile?. ¿Y en en la Región de La Araucanía? zona y region
#
# El porcentaje de encuestados a nivel nacional se encuentra principalmente en la zona urbana con un 81.2%, mientras que la rural con un 18.8%. En relación a nuestra región, ésta tambiién muestra una concentración en zona urbana, con un 66.7 %, aunque un poco más baja en comparación con el pais. La concetración rural en esta región es cercana al doble del porcentaje del pais.
#
# La variable "zona" nos proporciona el porcentaje de encuestados en las zonas urbanas y rurales. Haciendo un contraste con la variable "región" en La Araucanía.
#
# - 3. Muestre el ingreso promedio de los encuestados, por sexo, en las distintas regiones de Chile. ¿Es dónde es más alto y más bajo? ¿En alguna region de Chile es más alto el de las mujeres?.
#
# En Magallanes. Metropolitana y Aysén el ingreso promedio es más alto, mientras que para Ñuble, Maule y Araucanía los ingresos son los más bajos. En ninguna de las regiones del pais el ingreso de las mujeres es mayor al de los hombres.
#
# Las variables "y0101", "sexo" y "región" nos permiten conocer la distribución de ingresos por de hombres y mujeres por cada región.
#
# - 4. ¿Cuál es el nivel de escolaridad de los encuestados en la Región de la Araucania?. Muestre los primeros tres niveles del gráfico.
#
# Del gráfico se lee que más de 4000 encuestados cursaron o cursan el nivel de educación básica, entre 3000 a 4000 Educación Media Cientifico-Humanista y entre 1000 y 2000 Educación Media Técnico Profesional.
#
# Las variables cruzadas, "e6a" y "región", nos permiten obtener un conteo de la cantidad de encuestados que indican su nivel de escolaridad en la región de La Araucanía.
#
# - 5. A nivel nacional. ¿Cuál es el porcentaje de mujeres y hombres encuestados?. ¿Cuál es mayor?. Muestre en una tabla de procentaje
#
# En relación a los encuestados, los daton indican que un 52.26% equivale a mujeres y un 47.74% a hombres. Es mayor es de mujeres.
#
# La variable "sexo" permite distinguir a hombres y mujeres y obtener el porcentaje de ellos.
#
# - 6.¿Cuál es la principal razón por la cual las personas no asisten a un establecimiento educacional?
#
# Una de las razones principales es por trabaja o busca trabajo.
#
# La variable "e5a" nos permite conocer las razones principales de porque no asiste a un establecimiento educacional.
#
# Blancos 187.294
#
# - 7. En relación a la nacionalidad de los encuestados. ¿Cuál es la nacionalidad no chilena que predomina?.
#
# La nacionalidad que predomina entre los encuestados en la de Peruana, seguido por la de Argentinos.
#
# Las varibles "r1a" y "r1a_cod" permiten contabilizar entre los encuestados la nacionalidad de las personas no chilenas.
#
# Blancos 210.510
#
# - 8.¿Cuál es la principal razón por la cual las mujeres no se han hecho el papanicolau en los útimos 3 años?
#
# Se consideran tres grandes razones, la primera es que no le corresponde. La segunda es que no cree que lo necesite y la tercera es se le olvida hacérselo.
#
# La variable "s9" permite encontrar este tipo de respuesta en relación a las encuestadas en este módulo.
#
# Blancos 183.060
#
# - 9. Muestre las tres principales tipos de viviendas que predomina en los encuestados.
#
# Los tres principales tipos de viviendas que predominan entre los encuestados son: Casa aislada (no pareada), casa pareada por un lado y casa pareada por ambos lados, con 110.486, 57.069 y 27.948 encuestados respectivamente.
#
# La variable "v1" permite conocer las respuesta de los encuestados en relación al tipo de vivienda de cada encuestado.
#
# - 10. Muestre el porcentaje de situación de pobreza por ingresos para los encuestados.
#
# Los porcentajes muestran que encuestados no pobres estan en un 90.3%, pobres no extremos 7.1% y pobres extremos con 2.6%.
#
# La variable "pobreza" permite obtener datos de pobreza por ingreso en porcentaje de los encuestados para esta categoría.

# %%
datos['sexo']=datos['sexo'].replace({1.0:'Masculino', 2.0:'Femenino'})
datos['zona']=datos['zona'].replace({1.0:'Urbana', 2.0:'Rural'})
datos['region']=datos['region'].replace({1.0:'Tarapacá', 2.0:'Antofagasta', 3.0:'Atacama', 4.0:'Coquimbo', 5.0:'Valparaíso', 6.0:'O´Higgins', 7.0:'Maule', 8.0:'Biobío', 9.0:'Araucanía', 10.0:'Los Lagos', 11.0:'Aysén', 12.0:'Magallanes', 13.0:'Metropolitana', 14.0:'Los Ríos', 15.0:'Arica y Parinacota', 16.0:'Ñuble'})
datos['e6a']=datos['e6a'].replace({
    1: 'Nunca asistió',
    2: 'Sala cuna',
    3: 'Jardín Infantil (Medio menor y Medio mayor)',
    4: 'Prekinder/Kinder (Transición menor y Transición Mayor)',
    5: 'Educación Especial (Diferencial)',
    6: 'Primaria o Preparatoria (Sistema antiguo)',
    7: 'Educación Básica',
    8: 'Humanidades (Sistema Antiguo)',
    9: 'Educación Media Científico-Humanista',
    10: 'Técnica, Comercial, Industrial o Normalista (Sistema Antiguo)',
    11: 'Educación Media Técnica Profesional',
    12: 'Técnico Nivel Superior Incompleto (Carreras 1 a 3 años)',
    13: 'Técnico Nivel Superior Completo (Carreras 1 a 3 años)',
    14: 'Profesional Incompleto (Carreras 4 o más años)',
    15: 'Profesional Completo (Carreras 4 o más años)',
    16: 'Postgrado Incompleto',
    17: 'Postgrado Completo',
    99: 'No sabe/no responde'})
datos['r1a']=datos['r1a'].replace({1.0:'Chilena', 2.0:'Doble nacionalidad', 3.0:'Otra nacionalidad'})
datos['pobreza']=datos['pobreza'].replace({1.0:'Pobres extremos', 2.0:'Pobres no extremos', 3.0:'No pobres'})

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
# Calcular los conteos de cada categoría
conteos = datos.zona.value_counts()

# Crear el gráfico de torta
desfase = (0,0.1)
plt.figure(figsize=(4,4)) #plt. hace referencia a la librería matplotlib
plt.pie(conteos, labels=conteos.index, autopct='%0.1f%%',explode=desfase)

# Agregar un título al gráfico
plt.title('Distribución de la variable Zona en Chile',y=1.1) #y=1.1 cambia la posición del título

# Mostrar el gráfico
plt.axis('equal')  # Para que el gráfico sea un círculo en lugar de una elipse
plt.show()

# PERMITE VISIUALIZAR EL PORCENTAJE DE ENCUESTADOS QUE VIVE EN LA ZONA URBANA Y RURAL EN CHILE

# %%
# Calcular los conteos de cada categoría
region = 'Araucanía',
conteos = datos[datos['region'] == region]['zona'].value_counts()

# Crear el gráfico de torta
desfase = (0,0.1)
plt.figure(figsize=(4,4)) #plt. hace referencia a la librería matplotlib
plt.pie(conteos, labels=conteos.index, autopct='%0.1f%%',explode=desfase)

# Agregar un título al gráfico
plt.title('Distribución de la variable Zona en la Región de La Araucanía',y=1.1) #y=1.1 cambia la posición del título

# Mostrar el gráfico
plt.axis('equal')  # Para que el gráfico sea un círculo en lugar de una elipse
plt.show()

# PERMITE VISIUALIZAR EL PORCENTAJE DE ENCUESTADOS QUE VIVE EN LA ZONA URBANA Y RURAL EN LA REGIÓN DE LA ARAUCANÍA

# %%
#Gráfico de 
plt.figure(figsize=(20, 20))

# Utiliza sns.countplot para crear el gráfico de barras
count_plot = sns.countplot(x=datos.region, hue=datos.sexo)

# Establece el título del gráfico
plt.title('Gráfico de barras para la variable región y sexo', y=1.01)

# Establece las etiquetas de los ejes
plt.ylabel('Conteo')
plt.xlabel('Región')

plt.show()  # Muestra el gráfico

# PERMITE VISUALIZAR LA CANTIDAD DE ENCUESTADOS POR REGIÓN Y SEXO. DISTINGUIR QUE REGIÓN CONCENTRA LA MAYOR CANTIDAD DE ENCUESTADOS Y SI LOS QUE RESPONDEN SON MAYORITARIAMENTE MUJERES.

# %%
print('*' * 20, "Tabla de porcentajes para la variable Sexo", '*' * 20)
print(round(datos['sexo'].value_counts() / len(datos) * 100, 2))

# PERMITE OBTENER EL PORCENTAJE DE HOMBRES Y MUJERES QUE RESPONDIERON LA ENCUESTA
# Out:
# ******************** Tabla de porcentajes para la variable Sexo ********************
# Femenino     52.26
# Masculino    47.74
# Name: sexo, dtype: float64

# %%
plt.figure(figsize=(20, 20))  # Establece el tamaño del gráfico

# Filtra los datos para incluir solo un valor específico de la variable "región"
region_seleccionada = 'Araucanía'  # Reemplaza 'Valor Deseado' con el valor que deseas mostrar
datos_filtrados = datos[datos['region'] == region_seleccionada]

# Utiliza sns.countplot para crear el gráfico de barras con los datos filtrados
count_plot = sns.countplot(x=datos_filtrados.region, hue=datos_filtrados.e6a)

# Establece el título del gráfico
plt.title('Gráfico de barras para la variable Nivel educacional alzancazdo en la Región de La Araucanía', y=1.01)

# Establece las etiquetas de los ejes
plt.ylabel('Conteo')
plt.xlabel('Región')

plt.show()  # Muestra el gráfico

# PERMITE OBSERVAR EL NIVEL EDUCACIONAL ALCANZADO POR LOS ENCUESTADOS EN LA REGIÓN DE LA ARAUCANÍA

# %%
# Agrupar los datos por zona y sexo, y calcular la media de los ingresos
ingresos_por_zona_sexo = datos.groupby(['region', 'sexo'])['y0101'].mean().reset_index()

# Configurar el tamaño del gráfico
plt.figure(figsize=(25, 25))

# Utilizar seaborn para crear el gráfico de barras agrupado
sns.barplot(x='region', y='y0101', hue='sexo', data=ingresos_por_zona_sexo)

# Establecer título y etiquetas de los ejes
plt.title('Ingresos por region y sexo')
plt.xlabel('region')
plt.ylabel('Ingresos')

# Mostrar el gráfico
plt.show()

# PERMITE OBSERVAR EL NIVEL DE INGRESO PROMEDIO POR SEXO Y REGIÓN.

# %%
plt.figure(figsize=(4,4))
sns.histplot(datos['edad'], color='red', label='Femenino', alpha=0.5)
sns.histplot(datos['edad'], color='blue', label='Masculino', alpha=0.5)
plt.legend(loc='upper right')
plt.title('Histograma de la variable Edad agrupada por Sexo',y=1.01)
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.show()

# %%
datos['edad'].describe(include='all').loc[['mean', 'std', '25%', '50%', '75%', 'max']]
# Out:
# mean     37.780257
# std      22.950752
# 25%      19.000000
# 50%      36.000000
# 75%      56.000000
# max     117.000000
# Name: edad, dtype: float64

# %%
plt.figure(figsize=(4,4))
sns.boxplot(x=datos['sexo'],y=datos['edad']) #x debe ser categórica e y continua
plt.title('Diagrama de caja de la variable Edad por Sexo',y=1.01)
plt.xlabel('Sexo')
plt.show()

# %%
# Calcular los conteos de cada categoría
conteos = datos.pobreza.value_counts()

# Crear el gráfico de torta
desfase = (0,0,0.1)
plt.figure(figsize=(4,4)) #plt. hace referencia a la librería matplotlib
plt.pie(conteos, labels=conteos.index, autopct='%0.1f%%',explode=desfase)

# Agregar un título al gráfico
plt.title('Distribución de la variable Clase',y=1.1) #y=1.1 cambia la posición del título

# Mostrar el gráfico
plt.axis('equal')  # Para que el gráfico sea un círculo en lugar de una elipse
plt.show()
